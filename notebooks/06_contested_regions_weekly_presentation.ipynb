# %% [markdown]
# # 06 Contested Regions: Weekly Presentation Analysis
#
# Goal: turn the project brief's contested-region idea into presentation-ready evidence.
#
# This notebook uses already generated branch artifacts where possible. It focuses on:
#
# - defining contested regions in an operational way;
# - showing why annotation disagreement matters;
# - summarizing human-proteome annotation coverage;
# - surfacing the existing predictor-disagreement visuals;
# - creating weekly-presentation figures under `results/weekly_contested_regions/`.

# %% [markdown]
# ## Core definition
#
# A **contested region** is a contiguous protein fragment where calibrated disorder predictors disagree strongly about residue-level disorder.
#
# Working convention used throughout this project:
#
# - higher score means more disorder;
# - CheZOD is negated to match this direction;
# - pLDDT is converted to `1 - pLDDT / 100`;
# - predictors are calibrated before comparing spread, e.g. z-score or quantile normalization.
#
# First-pass region score:
#
# ```text
# residue_disagreement_i = robust_spread(z_1i, ..., z_ki)
# window_score = mean(residue_disagreement_i over a 30-residue window)
# ```
#
# For experiment prioritization, use:
#
# ```text
# priority = predictor_disagreement * boundary_uncertainty * experiment_suitability
# ```

# %%
from pathlib import Path
import json
import math
import textwrap

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display, Markdown

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent

RESULTS = ROOT / 'results'
OUT = RESULTS / 'weekly_contested_regions'
OUT.mkdir(parents=True, exist_ok=True)

plt.rcParams.update({
    'figure.dpi': 130,
    'savefig.dpi': 220,
    'font.size': 11,
    'axes.titlesize': 14,
    'axes.labelsize': 11,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'axes.spines.top': False,
    'axes.spines.right': False,
})

SLIDE = RESULTS / 'slide_enhanced_ceiling'
HUMAN = RESULTS / 'human_proteome_annotation_ceiling'
COMPARE = RESULTS / 'compare_predictors_with_seth_and_iupred3_and_adopt_and_metapredict'
ANNOT = RESULTS / 'annotation_ceiling'
ANNOT_MMSEQS = RESULTS / 'annotation_ceiling_mmseqs'

def read_csv(path, **kwargs):
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(path)
    return pd.read_csv(path, **kwargs)

def savefig(name):
    path = OUT / name
    plt.tight_layout()
    plt.savefig(path, bbox_inches='tight')
    print(f'saved: {path.relative_to(ROOT)}')
    return path

# %% [markdown]
# ## 1. Check available evidence
#
# These are the inputs this notebook expects. Missing files mean the corresponding plot cell should be skipped or regenerated by upstream scripts.

# %%
required = {
    'contested definition note': ROOT / 'docs' / 'contested_regions.md',
    'human overlap summary': HUMAN / 'human_proteome_overlap_summary.csv',
    'human overlap details': HUMAN / 'human_proteome_overlap_details.csv',
    'same vs cross concept': SLIDE / 'same_vs_cross_concept_summary.csv',
    'family agreement': SLIDE / 'annotation_family_agreement_summary.csv',
    'region-level agreement': SLIDE / 'region_level_agreement.csv',
    'primary biological compatibility': SLIDE / 'primary_ceiling_biological_compatibility.csv',
    'exact vs mmseqs80': SLIDE / 'exact_vs_mmseqs80_primary_ceiling.csv',
    'top contested regions figure': COMPARE / 'top_contested_regions.png',
    'PDBFlex outlier figure': COMPARE / 'contested_regions_pdbflex_outlier_profile.png',
    'predictor pairwise bars': COMPARE / 'predictor_pairwise_spearman_bars.png',
}

availability = pd.DataFrame([
    {'artifact': name, 'exists': path.exists(), 'path': str(path.relative_to(ROOT))}
    for name, path in required.items()
])
availability
# Out:
#                             artifact  exists  \
# 0          contested definition note    True
# 1              human overlap summary    True
# 2              human overlap details    True
# 3              same vs cross concept    True
# 4                   family agreement    True
# 5             region-level agreement    True
# 6   primary biological compatibility    True
# 7                  exact vs mmseqs80    True
# 8       top contested regions figure    True
# 9             PDBFlex outlier figure    True
# 10           predictor pairwise bars    True
#
#                                                  path
# 0                           docs/contested_regions.md
# 1   results/human_proteome_annotation_ceiling/huma...
# 2   results/human_proteome_annotation_ceiling/huma...
# 3   results/slide_enhanced_ceiling/same_vs_cross_c...
# 4   results/slide_enhanced_ceiling/annotation_fami...
# 5   results/slide_enhanced_ceiling/region_level_ag...
# 6   results/slide_enhanced_ceiling/primary_ceiling...
# 7   results/slide_enhanced_ceiling/exact_vs_mmseqs...
# 8   results/compare_predictors_with_seth_and_iupre...
# 9   results/compare_predictors_with_seth_and_iupre...
# 10  results/compare_predictors_with_seth_and_iupre...

# %% [markdown]
# ## 2. Human-proteome annotation coverage
#
# This plot answers: if we rank contested regions in the reviewed human proteome, how much existing UdonPred-style annotation can we use for direct validation?

# %%
human_summary = read_csv(HUMAN / 'human_proteome_overlap_summary.csv')
coverage = human_summary.copy()
coverage['matched_protein_pct'] = 100 * coverage['protein_overlap_fraction']
coverage['matched_valid_residue_pct'] = 100 * coverage['valid_annotated_residue_overlap_fraction']
coverage = coverage.sort_values('matched_valid_residue_pct', ascending=True)

fig, ax = plt.subplots(figsize=(9, 4.8))
y = np.arange(len(coverage))
ax.barh(y - 0.18, coverage['matched_protein_pct'], height=0.34, label='matched proteins', color='#4C78A8')
ax.barh(y + 0.18, coverage['matched_valid_residue_pct'], height=0.34, label='matched valid residues', color='#F58518')
ax.set_yticks(y)
ax.set_yticklabels(coverage['dataset'])
ax.set_xlabel('Human proteome overlap (%)')
ax.set_title('Existing labels cover only a small part of the human proteome')
ax.legend(frameon=False, loc='lower right')
for i, (_, row) in enumerate(coverage.iterrows()):
    ax.text(row['matched_valid_residue_pct'] + 0.7, i + 0.18, f"{row['matched_valid_residue_pct']:.1f}%", va='center', fontsize=9)
savefig('human_annotation_coverage.png')
plt.show()

coverage[['dataset', 'n_matched_human_proteins', 'matched_protein_pct', 'matched_valid_residue_pct']].sort_values('matched_valid_residue_pct', ascending=False)
# Out:
# saved: results/weekly_contested_regions/human_annotation_coverage.png
#    dataset  n_matched_human_proteins  matched_protein_pct  \
# 5    plddt                       114            43.018868
# 6  disprot                        83            26.018809
# 1   chezod                         5             4.273504
# 0   trizod                         4             1.149425
# 3  pdbflex                        14             1.061410
# 2  softdis                        17             0.909577
# 4    atlas                         0             0.000000
#
#    matched_valid_residue_pct
# 5                  46.891731
# 6                  27.300759
# 1                   4.767371
# 0                   1.491934
# 3                   1.339236
# 2                   1.278767
# 4                   0.000000

# %% [markdown]
# **Presentation takeaway:** pLDDT and DisProt have the broadest exact-sequence overlap with the reviewed human proteome in the existing evaluation sets. NMR chemical-shift annotations have very low direct human coverage, which makes disagreement-guided experimental selection relevant.

# %% [markdown]
# ## 3. Annotation concepts are not interchangeable
#
# Contested regions matter because disagreement is not just model noise. The project brief says different evidence sources measure different facets of disorder. The branch already has an annotation-ceiling analysis that makes this visible.

# %%
compat = read_csv(SLIDE / 'primary_ceiling_biological_compatibility.csv')
compat = compat[(compat['primary_metric'].isin(['spearman', 'auroc'])) & compat['value'].notna()].copy()
compat['display_pair'] = compat['pair'] + ' (' + compat['primary_metric'] + ')'
compat = compat.sort_values('value')

colors = {
    'low': '#E45756',
    'medium': '#F58518',
    'high': '#54A24B',
    'unknown/no-overlap': '#BAB0AC',
}
bar_colors = compat['expected_biological_similarity'].map(colors).fillna('#4C78A8')

fig, ax = plt.subplots(figsize=(10, max(5, 0.35 * len(compat))))
ax.barh(compat['display_pair'], compat['value'], color=bar_colors)
ax.set_xlabel('Primary annotation agreement ceiling')
ax.set_title('Real annotation agreement depends on the biological concept')
ax.axvline(0.5, color='black', lw=1, alpha=0.35)
for y_pos, value in enumerate(compat['value']):
    ax.text(value + 0.015, y_pos, f'{value:.2f}', va='center', fontsize=8)
savefig('annotation_concept_compatibility.png')
plt.show()

compat[['pair', 'family_a', 'family_b', 'expected_biological_similarity', 'primary_metric', 'value', 'n_residues_compared']].head(10)
# Out:
# saved: results/weekly_contested_regions/annotation_concept_compatibility.png
#                   pair                         family_a  \
# 12    pdbflex vs plddt  structural flexibility/dynamics
# 0   softdis vs pdbflex            derived soft disorder
# 11    pdbflex vs atlas  structural flexibility/dynamics
# 4    trizod vs pdbflex      NMR chemical-shift disorder
# 3      chezod vs atlas      NMR chemical-shift disorder
# 2       atlas vs plddt            derived soft disorder
# 10  pdbflex vs disprot  structural flexibility/dynamics
# 9     softdis vs atlas            derived soft disorder
# 20   chezod vs softdis      NMR chemical-shift disorder
# 1    trizod vs softdis      NMR chemical-shift disorder
#
#                            family_b expected_biological_similarity  \
# 12       AlphaFold confidence proxy                            low
# 0   structural flexibility/dynamics                            low
# 11            derived soft disorder                            low
# 4   structural flexibility/dynamics                            low
# 3             derived soft disorder                         medium
# 2        AlphaFold confidence proxy                         medium
# 10          curated binary disorder                            low
# 9             derived soft disorder                         medium
# 20            derived soft disorder                         medium
# 1             derived soft disorder                         medium
#
#    primary_metric     value  n_residues_compared
# 12       spearman  0.011500                 1412
# 0        spearman  0.077090               123212
# 11       spearman  0.111006                 2587
# 4        spearman  0.174514                  525
# 3        spearman  0.220828                  372
# 2        spearman  0.295052                  424
# 10          auroc  0.307951                 2335
# 9        spearman  0.315038                 1558
# 20       spearman  0.332540                   72
# 1        spearman  0.481151                  563

# %%
same_cross = read_csv(SLIDE / 'same_vs_cross_concept_summary.csv')
order = ['same annotation family', 'related disorder concept', 'different concept: flexibility vs disorder/proxy', 'unknown or weakly related']
same_cross['concept_relation'] = pd.Categorical(same_cross['concept_relation'], categories=order, ordered=True)
same_cross = same_cross.sort_values('concept_relation')

fig, ax = plt.subplots(figsize=(9, 4.8))
ax.bar(same_cross['concept_relation'].astype(str), same_cross['median_ceiling'], color='#4C78A8')
ax.set_ylabel('Median annotation ceiling')
ax.set_title('Median agreement drops when annotation concepts diverge')
ax.set_ylim(0, max(1.0, same_cross['median_ceiling'].max() + 0.1))
ax.tick_params(axis='x', rotation=25)
for i, row in same_cross.reset_index(drop=True).iterrows():
    ax.text(i, row['median_ceiling'] + 0.025, f"{row['median_ceiling']:.2f}\nn={int(row['n_pairs'])}", ha='center', va='bottom', fontsize=9)
savefig('same_vs_cross_concept_summary.png')
plt.show()

same_cross
# Out:
# saved: results/weekly_contested_regions/same_vs_cross_concept_summary.png
#                                    concept_relation  n_pairs  median_ceiling  \
# 1                            same annotation family        2        0.398508
# 0                          related disorder concept        8        0.492899
# 2  different concept: flexibility vs disorder/proxy        5        0.111006
#
#    mean_ceiling  median_overlap  \
# 1      0.398508           848.0
# 0      0.513992           493.5
# 2      0.136412          2335.0
#
#                                                pairs
# 1                 softdis vs atlas; trizod vs chezod
# 0  trizod vs softdis; atlas vs plddt; chezod vs a...
# 2  softdis vs pdbflex; trizod vs pdbflex; pdbflex...

# %% [markdown]
# **Presentation takeaway:** model disagreement should be interpreted by concept. PDBFlex/flexibility can be a valid signal but it is not the same biological target as NMR chemical-shift disorder or curated DisProt disorder.

# %% [markdown]
# ## 4. Exact matching vs. MMseqs matching
#
# This plot is useful for explaining why exact-overlap ceilings are conservative: local sequence matching can add comparable residues, but it may also change the apparent agreement.

# %%
exact_mm = read_csv(SLIDE / 'exact_vs_mmseqs80_primary_ceiling.csv')
exact_mm = exact_mm[exact_mm['exact_value'].notna() & exact_mm['mmseqs80_value'].notna()].copy()
exact_mm['residue_gain_label'] = exact_mm['residue_gain'].map(lambda x: f'{int(x):+d}')
exact_mm = exact_mm.sort_values('delta_mmseqs80_minus_exact')

fig, ax = plt.subplots(figsize=(10, max(4.5, 0.38 * len(exact_mm))))
colors = np.where(exact_mm['delta_mmseqs80_minus_exact'] >= 0, '#54A24B', '#E45756')
ax.barh(exact_mm['pair'], exact_mm['delta_mmseqs80_minus_exact'], color=colors)
ax.axvline(0, color='black', lw=1)
ax.set_xlabel('MMseqs80 ceiling minus exact-match ceiling')
ax.set_title('Local sequence matches can change estimated annotation agreement')
for y_pos, row in enumerate(exact_mm.itertuples()):
    ax.text(row.delta_mmseqs80_minus_exact + (0.02 if row.delta_mmseqs80_minus_exact >= 0 else -0.02),
            y_pos,
            f'{row.delta_mmseqs80_minus_exact:+.2f} / residues {int(row.residue_gain):+d}',
            va='center',
            ha='left' if row.delta_mmseqs80_minus_exact >= 0 else 'right',
            fontsize=8)
savefig('exact_vs_mmseqs80_delta.png')
plt.show()

exact_mm[['pair', 'exact_value', 'mmseqs80_value', 'delta_mmseqs80_minus_exact', 'exact_residues', 'mmseqs80_residues', 'concept_relation']]
# Out:
# saved: results/weekly_contested_regions/exact_vs_mmseqs80_delta.png
#                   pair  exact_value  mmseqs80_value  \
# 14   trizod vs softdis     0.481151        0.308778
# 13     chezod vs plddt     0.691031        0.563213
# 12    softdis vs plddt     0.656777        0.560025
# 11  softdis vs disprot     0.929907        0.883240
# 10      atlas vs plddt     0.295052        0.250323
# 9   pdbflex vs disprot     0.307951        0.274089
# 8    trizod vs pdbflex     0.174514        0.142931
# 7    chezod vs softdis     0.332540        0.301812
# 6      trizod vs plddt     0.504646        0.499411
# 5   softdis vs pdbflex     0.077090        0.141467
# 4     softdis vs atlas     0.315038        0.436362
# 3     pdbflex vs atlas     0.111006        0.286866
# 2     pdbflex vs plddt     0.011500        0.339407
# 1      chezod vs atlas     0.220828        0.623305
# 0     trizod vs chezod     0.481978        0.940091
#
#     delta_mmseqs80_minus_exact  exact_residues  mmseqs80_residues  \
# 14                   -0.172373             563               5847
# 13                   -0.127818            1385               4043
# 12                   -0.096752            2521              13219
# 11                   -0.046667            2642              12644
# 10                   -0.044729             424                737
# 9                    -0.033862            2335              10212
# 8                    -0.031583             525               5502
# 7                    -0.030728              72               1165
# 6                    -0.005235             283               1091
# 5                     0.064377          123212             201384
# 4                     0.121324            1558               7528
# 3                     0.175860            2587               7124
# 2                     0.327907            1412              10785
# 1                     0.402477             372                249
# 0                     0.458113             138                348
#
#                                     concept_relation
# 14                          related disorder concept
# 13                          related disorder concept
# 12                          related disorder concept
# 11                          related disorder concept
# 10                          related disorder concept
# 9   different concept: flexibility vs disorder/proxy
# 8   different concept: flexibility vs disorder/proxy
# 7                           related disorder concept
# 6                           related disorder concept
# 5   different concept: flexibility vs disorder/proxy
# 4                             same annotation family
# 3   different concept: flexibility vs disorder/proxy
# 2   different concept: flexibility vs disorder/proxy
# 1                           related disorder concept
# 0                             same annotation family

# %% [markdown]
# ## 5. Region-level agreement
#
# For presentation, residue-level correlations are abstract. Region-level overlap metrics are easier to explain: do two annotation sources mark the same stretches as disordered?

# %%
region = read_csv(SLIDE / 'region_level_agreement.csv')
region = region.sort_values('region_f1', ascending=True)

fig, ax = plt.subplots(figsize=(10, max(4.5, 0.36 * len(region))))
ax.barh(region['pair'], region['region_f1'], color='#72B7B2')
ax.set_xlabel('Region-level F1')
ax.set_title('Some annotation pairs agree on regions even when residue scores differ')
ax.set_xlim(0, 1.05)
for y_pos, row in enumerate(region.itertuples()):
    ax.text(row.region_f1 + 0.015, y_pos, f'{row.region_f1:.2f}', va='center', fontsize=8)
savefig('region_level_agreement.png')
plt.show()

region[['pair', 'family_a', 'family_b', 'n_residues', 'n_regions_a', 'n_regions_b', 'region_precision', 'region_recall', 'region_f1', 'residue_jaccard']]
# Out:
# saved: results/weekly_contested_regions/region_level_agreement.png
#                   pair                         family_a  \
# 14   chezod vs softdis      NMR chemical-shift disorder
# 15     chezod vs atlas      NMR chemical-shift disorder
# 13    pdbflex vs plddt  structural flexibility/dynamics
# 12      atlas vs plddt            derived soft disorder
# 11   trizod vs pdbflex      NMR chemical-shift disorder
# 10  softdis vs disprot            derived soft disorder
# 9   pdbflex vs disprot  structural flexibility/dynamics
# 8     softdis vs plddt            derived soft disorder
# 7     pdbflex vs atlas  structural flexibility/dynamics
# 6   softdis vs pdbflex            derived soft disorder
# 5      chezod vs plddt      NMR chemical-shift disorder
# 4    trizod vs softdis      NMR chemical-shift disorder
# 3     softdis vs atlas            derived soft disorder
# 2      trizod vs plddt      NMR chemical-shift disorder
# 1     trizod vs chezod      NMR chemical-shift disorder
# 0    chezod vs disprot      NMR chemical-shift disorder
#
#                            family_b  n_residues  n_regions_a  n_regions_b  \
# 14            derived soft disorder          72            0            4
# 15            derived soft disorder         372            0           25
# 13       AlphaFold confidence proxy        1412           16           14
# 12       AlphaFold confidence proxy         424           27            2
# 11  structural flexibility/dynamics         525            5            7
# 10          curated binary disorder        2642           77            9
# 9           curated binary disorder        2335           23            8
# 8        AlphaFold confidence proxy        2521           68           20
# 7             derived soft disorder        2587           42          175
# 6   structural flexibility/dynamics      123000         3741         1283
# 5        AlphaFold confidence proxy        1385           74           41
# 4             derived soft disorder         563           10           17
# 3             derived soft disorder        1558           55          114
# 2        AlphaFold confidence proxy         283            5            3
# 1       NMR chemical-shift disorder         138            4            9
# 0           curated binary disorder         465           39            1
#
#     region_precision  region_recall  region_f1  residue_jaccard
# 14          0.000000       0.000000   0.000000         0.000000
# 15          0.000000       0.000000   0.000000         0.000000
# 13          0.062500       0.071429   0.066667         0.004673
# 12          0.074074       1.000000   0.137931         0.050000
# 11          0.400000       0.142857   0.210526         0.038961
# 10          0.129870       0.777778   0.222576         0.353896
# 9           0.173913       0.375000   0.237624         0.088235
# 8           0.147059       0.950000   0.254692         0.272036
# 7           0.833333       0.177143   0.292177         0.143693
# 6           0.230420       0.694466   0.346029         0.130109
# 5           0.297297       0.609756   0.399709         0.142191
# 4           0.900000       0.294118   0.443350         0.368056
# 3           0.945455       0.333333   0.492891         0.250758
# 2           0.400000       1.000000   0.571429         0.143939
# 1           0.750000       1.000000   0.857143         0.729323
# 0           1.000000       1.000000   1.000000         0.610753

# %% [markdown]
# ## 6. Existing predictor-disagreement visuals
#
# The following figures already exist in the branch and are directly usable in weekly slides.

# %%
figure_paths = [
    COMPARE / 'predictor_pairwise_spearman_bars.png',
    COMPARE / 'top_contested_regions.png',
    COMPARE / 'contested_regions_pdbflex_outlier_profile.png',
    COMPARE / 'predictor_vs_udonpred_consensus.png',
    COMPARE / 'udon_predictor_annotation_residue_gap_exact_vs_mmseqs.png',
]

for path in figure_paths:
    if path.exists():
        display(Markdown(f'### `{path.relative_to(ROOT)}`'))
        display(Image(filename=str(path)))
    else:
        display(Markdown(f'**Missing:** `{path.relative_to(ROOT)}`'))
# Out:
# ### `results/compare_predictors_with_seth_and_iupred3_and_adopt_and_metapredict/predictor_pairwise_spearman_bars.png`
# ### `results/compare_predictors_with_seth_and_iupred3_and_adopt_and_metapredict/top_contested_regions.png`
# ### `results/compare_predictors_with_seth_and_iupred3_and_adopt_and_metapredict/contested_regions_pdbflex_outlier_profile.png`
# ### `results/compare_predictors_with_seth_and_iupred3_and_adopt_and_metapredict/predictor_vs_udonpred_consensus.png`
# ### `results/compare_predictors_with_seth_and_iupred3_and_adopt_and_metapredict/udon_predictor_annotation_residue_gap_exact_vs_mmseqs.png`

# %% [markdown]
# ## 7. Presentation-ready contested-region ranking
#
# The branch already has `top_contested_regions.png`; the raw table was not checked into the repo. For weekly slides, this cell recreates a compact table from the visible top entries in that figure and saves a cleaner bar chart.
#
# If a raw table becomes available later, replace the literal table below with a `read_csv(...)` call.

# %%
top_regions = pd.DataFrame([
    ('P48594', 331, 360, 2.17),
    ('P01011', 361, 390, 2.09),
    ('P29508', 331, 360, 2.06),
    ('Q9UIV8', 331, 360, 1.99),
    ('P01009', 361, 390, 1.99),
    ('Q86WD7', 361, 390, 1.97),
    ('O75830', 331, 360, 1.94),
    ('P29622', 361, 390, 1.94),
    ('Q9UK55', 391, 420, 1.91),
    ('O95140', 601, 630, 1.89),
    ('O75635', 331, 360, 1.88),
    ('Q96P15', 331, 360, 1.85),
    ('O95236', 181, 210, 1.82),
    ('P05155', 451, 480, 1.82),
    ('Q8IW75', 361, 390, 1.81),
], columns=['accession', 'start', 'end', 'mean_disagreement'])
top_regions['region'] = top_regions['accession'] + ':' + top_regions['start'].astype(str) + '-' + top_regions['end'].astype(str)

top_regions = top_regions.sort_values('mean_disagreement', ascending=True)
fig, ax = plt.subplots(figsize=(9.5, 6.2))
ax.barh(top_regions['region'], top_regions['mean_disagreement'], color='#C44E52')
ax.set_xlabel('Average predictor disagreement in 30-residue window')
ax.set_title('Top contested human-proteome regions')
for y_pos, value in enumerate(top_regions['mean_disagreement']):
    ax.text(value + 0.025, y_pos, f'{value:.2f}', va='center', fontsize=9)
savefig('top_contested_regions_replotted.png')
plt.show()

top_regions.sort_values('mean_disagreement', ascending=False)
# Out:
# saved: results/weekly_contested_regions/top_contested_regions_replotted.png
#    accession  start  end  mean_disagreement          region
# 0     P48594    331  360               2.17  P48594:331-360
# 1     P01011    361  390               2.09  P01011:361-390
# 2     P29508    331  360               2.06  P29508:331-360
# 3     Q9UIV8    331  360               1.99  Q9UIV8:331-360
# 4     P01009    361  390               1.99  P01009:361-390
# 5     Q86WD7    361  390               1.97  Q86WD7:361-390
# 6     O75830    331  360               1.94  O75830:331-360
# 7     P29622    361  390               1.94  P29622:361-390
# 8     Q9UK55    391  420               1.91  Q9UK55:391-420
# 9     O95140    601  630               1.89  O95140:601-630
# 10    O75635    331  360               1.88  O75635:331-360
# 11    Q96P15    331  360               1.85  Q96P15:331-360
# 12    O95236    181  210               1.82  O95236:181-210
# 13    P05155    451  480               1.82  P05155:451-480
# 14    Q8IW75    361  390               1.81  Q8IW75:361-390

# %% [markdown]
# **Presentation takeaway:** the highest-ranked windows cluster around 30-residue segments with very large normalized predictor spread. The existing outlier plot suggests many are driven by a high PDBFlex-head score relative to the median predictor, so these are likely flexibility-vs-disorder conflicts.

# %% [markdown]
# ## 8. Proposed contested-region score visual
#
# This is a conceptual slide figure: predictor disagreement is necessary but not sufficient. The most useful experimental candidates should also be near the decision boundary and practical for NMR follow-up.

# %%
fig, ax = plt.subplots(figsize=(10, 4.2))
ax.axis('off')

boxes = [
    (0.05, 0.54, 0.23, 0.28, 'Predictor\ndisagreement', 'robust spread across\ncalibrated predictors'),
    (0.39, 0.54, 0.23, 0.28, 'Boundary\nuncertainty', 'consensus near\norder/disorder threshold'),
    (0.73, 0.54, 0.23, 0.28, 'Experiment\nsuitability', 'fragment length, solubility,\nno obvious artifacts'),
    (0.32, 0.10, 0.36, 0.25, 'Ranked contested\nregions', 'highest expected information\ngain for new annotation'),
]

for x, y, w, h, title, subtitle in boxes:
    rect = plt.Rectangle((x, y), w, h, transform=ax.transAxes, facecolor='#F2F2F2', edgecolor='#4C78A8', linewidth=1.8)
    ax.add_patch(rect)
    ax.text(x + w/2, y + h*0.66, title, ha='center', va='center', transform=ax.transAxes, fontsize=14, weight='bold')
    ax.text(x + w/2, y + h*0.28, subtitle, ha='center', va='center', transform=ax.transAxes, fontsize=10)

for x0, x1 in [(0.28, 0.39), (0.62, 0.73)]:
    ax.annotate('', xy=(x1, 0.68), xytext=(x0, 0.68), xycoords=ax.transAxes,
                arrowprops=dict(arrowstyle='->', lw=2, color='#666666'))
for x0 in [0.165, 0.505, 0.845]:
    ax.annotate('', xy=(0.50, 0.35), xytext=(x0, 0.54), xycoords=ax.transAxes,
                arrowprops=dict(arrowstyle='->', lw=1.8, color='#666666'))

ax.text(0.50, 0.92, 'Contested-region priority = disagreement × uncertainty × suitability',
        ha='center', transform=ax.transAxes, fontsize=15, weight='bold')
savefig('contested_region_scoring_concept.png')
plt.show()
# Out:
# saved: results/weekly_contested_regions/contested_region_scoring_concept.png

# %% [markdown]
# ## 9. Candidate slide sequence
#
# 1. **Problem:** disorder annotations measure different biology, so labels disagree.
# 2. **Evidence:** annotation-ceiling plot showing concept-dependent agreement.
# 3. **Coverage gap:** human-proteome exact overlap is limited, especially for NMR labels.
# 4. **Predictor disagreement:** pairwise predictor agreement plot, highlighting PDBFlex as weakly aligned with disorder predictors.
# 5. **Contested regions:** top 30-residue windows by calibrated predictor spread.
# 6. **Interpretation:** many top windows are PDBFlex-high outliers, suggesting flexibility-vs-disorder conflict.
# 7. **Next step:** rank windows by disagreement × boundary uncertainty × NMR suitability, then validate retrospectively against later BMRB coverage.

# %% [markdown]
# ## 11. Full contested-region pipeline output
#
# The first version of this notebook used existing PNGs. The repository now has a reusable script:
#
# ```bash
# python3 scripts/analyze_contested_regions.py --target-dataset plddt --output-dir results/contested_regions/plddt
# ```
#
# It creates the actual window-level table requested for follow-up analysis:
#
# - `contested_windows.csv`: all scored windows;
# - `top_contested_windows.csv`: ranked experimental candidates;
# - `disagreement_type_summary.csv`: PDBFlex-high, pLDDT-outlier, NMR-vs-curated, broad-spread classes;
# - `feature_enrichment_top_vs_background.csv`: sequence feature enrichment;
# - `validation_summary.csv`: sanity checks and label-boundary correlation;
# - `case_studies/*.png`: predictor tracks for top-ranked regions.
#
# The current checked-in raw human predictor outputs are not available, so the verified run below uses the existing UdonPred cross-head predictions on the pLDDT target set. The same script supports future human-proteome outputs with `--layout generic --prediction-root <folder>`.

# %%
CONTESTED = RESULTS / 'contested_regions' / 'plddt'
for required_file in [
    'contested_windows.csv',
    'top_contested_windows.csv',
    'disagreement_type_summary.csv',
    'feature_enrichment_top_vs_background.csv',
    'validation_summary.csv',
]:
    path = CONTESTED / required_file
    print(f'{required_file}:', 'ok' if path.exists() else 'missing')
# Out:
# contested_windows.csv: ok
# top_contested_windows.csv: ok
# disagreement_type_summary.csv: ok
# feature_enrichment_top_vs_background.csv: ok
# validation_summary.csv: ok

# %% [markdown]
# ### Ranked candidate table
#
# This is the core table for deciding which regions to discuss as experimental candidates.

# %%
contested_windows = read_csv(CONTESTED / 'contested_windows.csv')
top_contested = read_csv(CONTESTED / 'top_contested_windows.csv')
cols = [
    'protein_id', 'start', 'end', 'priority_score', 'mean_disagreement',
    'boundary_uncertainty', 'nmr_suitability', 'disagreement_type',
    'top_predictor', 'bottom_predictor', 'top_minus_bottom_z',
    'hydropathy', 'net_charge', 'frac_pro_gly', 'low_complexity',
    'has_human_overlap', 'human_accessions', 'human_genes',
]
top_contested[[col for col in cols if col in top_contested.columns]].head(15)
# Out:
#    protein_id  start   end  priority_score  mean_disagreement  \
# 0     DP00689     41    70        0.990576           1.560453
# 1     DP00689     51    80        0.943669           1.475126
# 2     DP01582   1021  1050        0.932225           1.002668
# 3     DP01582   1031  1060        0.913684           1.026736
# 4     DP00605      1    30        0.866205           1.200024
# 5     DP01582    221   250        0.850220           0.888950
# 6     DP00119     71   100        0.819930           1.367970
# 7     DP00151    141   170        0.817970           0.850233
# 8     DP00119     81   110        0.810539           1.329633
# 9     DP00119     91   120        0.803380           1.296350
# 10    DP00119     61    90        0.799477           1.393886
# 11    DP01582   1081  1110        0.761729           0.889016
# 12    DP00530     11    40        0.760634           1.373246
# 13    DP00119     51    80        0.751588           1.364587
# 14    DP00689     31    60        0.745300           1.324688
#
#     boundary_uncertainty  nmr_suitability  \
# 0               0.687700         0.923077
# 1               0.677965         0.943590
# 2               0.955220         0.973330
# 3               0.918828         0.968508
# 4               0.730253         0.988456
# 5               0.959430         0.996875
# 6               0.617129         0.971234
# 7               0.968104         0.993750
# 8               0.611507         0.996875
# 9               0.640140         0.968109
# 10              0.573560         1.000000
# 11              0.859508         0.996875
# 12              0.559137         0.990625
# 13              0.573146         0.960978
# 14              0.616357         0.912821
#
#                          disagreement_type top_predictor bottom_predictor  \
# 0                  broad_multimodel_spread       disprot          softdis
# 1   possible_molecular_recognition_element       disprot          softdis
# 2   possible_molecular_recognition_element       pdbflex          softdis
# 3   possible_molecular_recognition_element         plddt            atlas
# 4   possible_molecular_recognition_element       softdis          pdbflex
# 5   possible_molecular_recognition_element       pdbflex          softdis
# 6                  broad_multimodel_spread       disprot          softdis
# 7   possible_molecular_recognition_element        trizod            plddt
# 8   possible_molecular_recognition_element       disprot          softdis
# 9   possible_molecular_recognition_element       disprot          softdis
# 10  possible_molecular_recognition_element       disprot          softdis
# 11  possible_molecular_recognition_element       pdbflex            atlas
# 12  possible_molecular_recognition_element        trizod          softdis
# 13                 broad_multimodel_spread        trizod          softdis
# 14                 broad_multimodel_spread        trizod          softdis
#
#     top_minus_bottom_z  hydropathy  net_charge  frac_pro_gly  low_complexity  \
# 0             2.590262   -0.873333    0.000000      0.600000        0.600000
# 1             2.579083   -0.860000   -0.033333      0.533333        0.533333
# 2             1.265871   -0.260000    0.100000      0.100000        0.100000
# 3             1.324242   -0.226667    0.133333      0.100000        0.133333
# 4             1.768047   -1.930000    0.166667      0.000000        0.233333
# 5             1.755123   -1.250000    0.066667      0.133333        0.166667
# 6             2.327537   -2.016667    0.066667      0.633333        0.433333
# 7             1.325859   -1.030000   -0.166667      0.066667        0.233333
# 8             2.267663   -2.136667    0.100000      0.533333        0.333333
# 9             2.306478   -2.006667    0.133333      0.633333        0.433333
# 10            2.281729   -2.010000    0.033333      0.566667        0.333333
# 11            1.346077   -0.866667   -0.133333      0.066667        0.166667
# 12            1.890846   -1.033333    0.133333      0.366667        0.333333
# 13            2.147658   -1.826667    0.033333      0.700000        0.466667
# 14            2.302601   -0.590000    0.000000      0.633333        0.633333
#
#     has_human_overlap human_accessions human_genes
# 0               False              NaN         NaN
# 1               False              NaN         NaN
# 2               False              NaN         NaN
# 3               False              NaN         NaN
# 4               False              NaN         NaN
# 5               False              NaN         NaN
# 6                True           P10163        PRB4
# 7               False              NaN         NaN
# 8                True           P10163        PRB4
# 9                True           P10163        PRB4
# 10               True           P10163        PRB4
# 11              False              NaN         NaN
# 12              False              NaN         NaN
# 13               True           P10163        PRB4
# 14              False              NaN         NaN

# %% [markdown]
# ### Disagreement-type classes
#
# This turns a variance score into a biological interpretation: flexibility-vs-disorder outliers, pLDDT uncertainty outliers, NMR-vs-curated conflicts, broad multi-model spread, and general spread.

# %%
disagreement_type_summary = read_csv(CONTESTED / 'disagreement_type_summary.csv')
disagreement_type_summary
# Out:
#                         disagreement_type  n_windows  median_priority  \
# 0  possible_molecular_recognition_element        206         0.539566
# 1               plddt_uncertainty_outlier         12         0.477091
# 2                 broad_multimodel_spread         38         0.395807
# 3                 nmr_vs_curated_conflict         40         0.393521
# 4                    pdbflex_high_outlier        445         0.332878
# 5     tmh_or_signal_peptide_like_artifact         80         0.230167
# 6                general_predictor_spread       4824         0.175061
#
#    median_disagreement  median_boundary_uncertainty  median_nmr_suitability
# 0             0.824385                     0.632911                0.993750
# 1             0.613080                     0.861344                0.989568
# 2             0.948452                     0.433540                0.990625
# 3             1.046924                     0.391043                0.990625
# 4             0.419086                     0.848262                0.987623
# 5             0.393954                     0.655609                0.797085
# 6             0.301944                     0.597800                0.989596

# %%
for name in [
    'top_contested_windows.png',
    'disagreement_type_counts.png',
    'feature_enrichment_top_vs_background.png',
    'disagreement_vs_boundary_uncertainty.png',
]:
    path = CONTESTED / name
    if path.exists():
        display(Markdown(f'### `{path.relative_to(ROOT)}`'))
        display(Image(filename=str(path)))
# Out:
# ### `results/contested_regions/plddt/top_contested_windows.png`
# ### `results/contested_regions/plddt/disagreement_type_counts.png`
# ### `results/contested_regions/plddt/feature_enrichment_top_vs_background.png`
# ### `results/contested_regions/plddt/disagreement_vs_boundary_uncertainty.png`

# %% [markdown]
# ### Feature enrichment and validation
#
# This checks whether top contested windows have distinctive sequence properties and whether disagreement relates to target-label boundary ambiguity.

# %%
feature_enrichment = read_csv(CONTESTED / 'feature_enrichment_top_vs_background.csv')
validation = read_csv(CONTESTED / 'validation_summary.csv')
display(feature_enrichment)
display(validation)
# Out:
#                       feature  top5_mean  background_mean  \
# 0     longest_hydrophobic_run   2.441696         3.059306
# 1                  hydropathy  -0.770365        -0.483718
# 2         possible_more_score   0.833359         0.625149
# 3         percent_hydrophobic   0.325324         0.373894
# 4              tmh_like_score   0.040099         0.082706
# 5             nors_like_score   0.181308         0.143277
# 6             coil_like_score   0.185328         0.150804
# 7                frac_pro_gly   0.152179         0.124306
# 8              low_complexity   0.199176         0.173413
# 9   signal_peptide_like_score   0.050683         0.071609
# 10               frac_glycine   0.091166         0.070525
# 11                 net_charge   0.019435         0.007093
# 12                 frac_polar   0.259835         0.248736
# 13          positive_fraction   0.156302         0.145673
# 14              frac_aromatic   0.069729         0.079699
# 15               frac_charged   0.293168         0.284253
# 16               frac_proline   0.061013         0.053781
# 17          negative_fraction   0.136867         0.138580
# 18           frac_nonstandard   0.000000         0.000000
#
#     delta_top_minus_background
# 0                    -0.617610
# 1                    -0.286647
# 2                     0.208209
# 3                    -0.048570
# 4                    -0.042608
# 5                     0.038032
# 6                     0.034524
# 7                     0.027873
# 8                     0.025763
# 9                    -0.020927
# 10                    0.020641
# 11                    0.012342
# 12                    0.011100
# 13                    0.010628
# 14                   -0.009970
# 15                    0.008915
# 16                    0.007232
# 17                   -0.001713
# 18                    0.000000
#                                               metric        value
# 0                                          n_windows  5645.000000
# 1                                         n_proteins   265.000000
# 2                              median_priority_score     0.196749
# 3                         top5pct_priority_threshold     0.477117
# 4                        fraction_with_human_overlap     0.473694
# 5  spearman_disagreement_vs_label_boundary_uncert...    -0.430228

# %% [markdown]
# ### Case-study panels
#
# Each panel shows calibrated predictor tracks around a top-ranked region. These are the most useful weekly-slide visuals because they show exactly which predictors disagree and where.

# %%
case_dir = CONTESTED / 'case_studies'
for path in sorted(case_dir.glob('*.png'))[:5]:
    display(Markdown(f'### `{path.relative_to(ROOT)}`'))
    display(Image(filename=str(path)))
# Out:
# ### `results/contested_regions/plddt/case_studies/DP00605_1_30.png`
# ### `results/contested_regions/plddt/case_studies/DP00689_41_70.png`
# ### `results/contested_regions/plddt/case_studies/DP00689_51_80.png`
# ### `results/contested_regions/plddt/case_studies/DP01582_1021_1050.png`
# ### `results/contested_regions/plddt/case_studies/DP01582_1031_1060.png`

# %% [markdown]
# ## 12. Immediate follow-up after raw human predictions exist
#
# Run the same pipeline on human-proteome predictor outputs laid out as:
#
# ```text
# results/human_predictor_outputs/
#   trizod/*.caid
#   chezod/*.caid
#   softdis/*.caid
#   pdbflex/*.caid
#   atlas/*.caid
#   plddt/*.caid
#   disprot/*.caid
#   seth/*.caid
#   iupred3/*.caid
#   adopt/*.caid
#   metapredict/*.caid
# ```
#
# Then execute:
#
# ```bash
# python3 scripts/analyze_contested_regions.py \
#   --layout generic \
#   --prediction-root results/human_predictor_outputs \
#   --target-dataset human \
#   --output-dir results/contested_regions/human
# ```
#
# That will produce the same ranked window table, disagreement classes, feature enrichment, and case-study plots for the actual reviewed human proteome.

# %% [markdown]
# ## 13. Lecture-derived biological controls
#
# The lecture slides add several biological controls that make the contested-region analysis more defensible:
#
# - disorder can mean long no-regular-secondary-structure regions, B-value/flexibility, contact-deprived regions, NMR chemical-shift disorder, or embedding-based disorder;
# - B-values/flexibility are not directly equivalent to intrinsic disorder, so PDBFlex-high windows need their own interpretation;
# - transmembrane helices and signal peptides are hydrophobic, segment-like cases that can look unusual to disorder predictors and are poor NMR candidates;
# - low pLDDT is useful as a disorder proxy, but it is still an AlphaFold confidence score;
# - MoRE-like regions are interesting because some disordered regions become structured upon binding.
#
# The script now adds these lecture-derived columns to `contested_windows.csv`: `tmh_like_score`, `signal_peptide_like_score`, `coil_like_score`, `nors_like_score`, `possible_more_score`, `concept_family_spread_z`, and `plddt_confidence_class`.

# %%
lecture_summary = read_csv(CONTESTED / 'lecture_extension_summary.csv')
lecture_summary
# Out:
#              lecture_control  median_all_windows  median_top5pct_priority  \
# 0    concept_family_spread_z            0.595372                 1.229539
# 1        possible_more_score            0.632217                 0.836739
# 2             tmh_like_score            0.030451                 0.000000
# 3  signal_peptide_like_score            0.054088                 0.031250
# 4            nors_like_score            0.133833                 0.151770
# 5            coil_like_score            0.140796                 0.155500
#
#    top5pct_minus_all
# 0           0.634167
# 1           0.204522
# 2          -0.030451
# 3          -0.022838
# 4           0.017937
# 5           0.014704

# %%
for name in [
    'lecture_controls_top_vs_all.png',
    'lecture_controls_top_windows_profile.png',
]:
    path = CONTESTED / name
    if path.exists():
        display(Markdown(f'### `{path.relative_to(ROOT)}`'))
        display(Image(filename=str(path)))
# Out:
# ### `results/contested_regions/plddt/lecture_controls_top_vs_all.png`
# ### `results/contested_regions/plddt/lecture_controls_top_windows_profile.png`

# %% [markdown]
# ### Lecture-informed interpretation table
#
# This table shows the new biological controls next to the top-ranked windows. Use it to decide whether a candidate is a clean experimental target, a possible MoRE/binding motif, or likely a membrane/signal-peptide artifact.

# %%
lecture_cols = [
    'protein_id', 'start', 'end', 'priority_score', 'disagreement_type',
    'concept_family_spread_z', 'possible_more_score', 'tmh_like_score',
    'signal_peptide_like_score', 'coil_like_score', 'nors_like_score',
    'plddt_confidence_class', 'percent_hydrophobic', 'net_charge',
    'low_complexity', 'top_predictor', 'bottom_predictor',
]
top_contested[[col for col in lecture_cols if col in top_contested.columns]].head(20)
# Out:
#    protein_id  start   end  priority_score  \
# 0     DP00689     41    70        0.990576
# 1     DP00689     51    80        0.943669
# 2     DP01582   1021  1050        0.932225
# 3     DP01582   1031  1060        0.913684
# 4     DP00605      1    30        0.866205
# 5     DP01582    221   250        0.850220
# 6     DP00119     71   100        0.819930
# 7     DP00151    141   170        0.817970
# 8     DP00119     81   110        0.810539
# 9     DP00119     91   120        0.803380
# 10    DP00119     61    90        0.799477
# 11    DP01582   1081  1110        0.761729
# 12    DP00530     11    40        0.760634
# 13    DP00119     51    80        0.751588
# 14    DP00689     31    60        0.745300
# 15    DP01582    211   240        0.743302
# 16    DP00151    151   180        0.738212
# 17    DP01582   1011  1040        0.736283
# 18    DP00689     61    90        0.731133
# 19    DP01854     11    40        0.725314
#
#                          disagreement_type  concept_family_spread_z  \
# 0                  broad_multimodel_spread                 1.678582
# 1   possible_molecular_recognition_element                 1.507532
# 2   possible_molecular_recognition_element                 1.199204
# 3   possible_molecular_recognition_element                 1.263040
# 4   possible_molecular_recognition_element                 1.567251
# 5   possible_molecular_recognition_element                 1.707608
# 6                  broad_multimodel_spread                 1.445955
# 7   possible_molecular_recognition_element                 1.247597
# 8   possible_molecular_recognition_element                 1.323234
# 9   possible_molecular_recognition_element                 1.412969
# 10  possible_molecular_recognition_element                 1.412044
# 11  possible_molecular_recognition_element                 1.337487
# 12  possible_molecular_recognition_element                 1.714955
# 13                 broad_multimodel_spread                 1.558751
# 14                 broad_multimodel_spread                 1.281063
# 15  possible_molecular_recognition_element                 1.319167
# 16  possible_molecular_recognition_element                 1.124984
# 17  possible_molecular_recognition_element                 1.030679
# 18                 broad_multimodel_spread                 1.059617
# 19  possible_molecular_recognition_element                 1.581720
#
#     possible_more_score  tmh_like_score  signal_peptide_like_score  \
# 0              0.770900        0.000000                   0.000000
# 1              0.807021        0.000000                   0.000000
# 2              0.887156        0.102101                   0.062500
# 3              0.920448        0.102101                   0.110714
# 4              0.930015        0.026471                   0.062500
# 5              0.900949        0.000000                   0.031250
# 6              0.776478        0.000000                   0.031250
# 7              0.888962        0.000000                   0.062500
# 8              0.835409        0.000000                   0.031250
# 9              0.785525        0.000000                   0.062500
# 10             0.808938        0.000000                   0.000000
# 11             0.913847        0.000000                   0.031250
# 12             0.825268        0.000000                   0.093750
# 13             0.723055        0.000000                   0.031250
# 14             0.712528        0.000000                   0.000000
# 15             0.844295        0.000000                   0.062500
# 16             0.875341        0.000000                   0.031250
# 17             0.838113        0.000000                   0.031250
# 18             0.774511        0.000000                   0.000000
# 19             0.806972        0.000000                   0.062500
#
#     coil_like_score  nors_like_score  \
# 0          0.426833         0.426833
# 1          0.401963         0.401963
# 2          0.134296         0.120585
# 3          0.145352         0.130511
# 4          0.204778         0.199357
# 5          0.247796         0.247796
# 6          0.571111         0.571111
# 7          0.145093         0.145093
# 8          0.495648         0.495648
# 9          0.567852         0.567852
# 10         0.488611         0.488611
# 11         0.132630         0.132630
# 12         0.321000         0.321000
# 13         0.577556         0.577556
# 14         0.447185         0.447185
# 15         0.154019         0.154019
# 16         0.183593         0.183593
# 17         0.172407         0.172407
# 18         0.396111         0.396111
# 19         0.222833         0.222833
#
#                           plddt_confidence_class  percent_hydrophobic  \
# 0                              plddt_not_outlier             0.133333
# 1                              plddt_not_outlier             0.133333
# 2                              plddt_not_outlier             0.433333
# 3   plddt_low_confidence_with_disorder_consensus             0.400000
# 4                              plddt_not_outlier             0.300000
# 5                              plddt_not_outlier             0.233333
# 6                              plddt_not_outlier             0.000000
# 7                              plddt_not_outlier             0.333333
# 8                              plddt_not_outlier             0.000000
# 9                              plddt_not_outlier             0.000000
# 10                             plddt_not_outlier             0.000000
# 11  plddt_low_confidence_with_disorder_consensus             0.366667
# 12                             plddt_not_outlier             0.166667
# 13                             plddt_not_outlier             0.000000
# 14                             plddt_not_outlier             0.166667
# 15                             plddt_not_outlier             0.333333
# 16                             plddt_not_outlier             0.266667
# 17                             plddt_not_outlier             0.366667
# 18                             plddt_not_outlier             0.133333
# 19                             plddt_not_outlier             0.233333
#
#     net_charge  low_complexity top_predictor bottom_predictor
# 0     0.000000        0.600000       disprot          softdis
# 1    -0.033333        0.533333       disprot          softdis
# 2     0.100000        0.100000       pdbflex          softdis
# 3     0.133333        0.133333         plddt            atlas
# 4     0.166667        0.233333       softdis          pdbflex
# 5     0.066667        0.166667       pdbflex          softdis
# 6     0.066667        0.433333       disprot          softdis
# 7    -0.166667        0.233333        trizod            plddt
# 8     0.100000        0.333333       disprot          softdis
# 9     0.133333        0.433333       disprot          softdis
# 10    0.033333        0.333333       disprot          softdis
# 11   -0.133333        0.166667       pdbflex            atlas
# 12    0.133333        0.333333        trizod          softdis
# 13    0.033333        0.466667        trizod          softdis
# 14    0.000000        0.633333        trizod          softdis
# 15    0.000000        0.133333       pdbflex          softdis
# 16   -0.166667        0.266667        trizod            plddt
# 17    0.133333        0.133333         plddt          softdis
# 18    0.066667        0.500000       disprot          softdis
# 19    0.033333        0.200000        trizod          softdis

# %% [markdown]
# **Presentation takeaway:** top-priority windows are enriched for concept-family spread, meaning the strongest candidates are not only single-predictor noise. TMH/signal-like scores are lower in the top-priority set, which is good: the ranking is not dominated by obvious membrane artifacts. The MoRE score highlights a smaller set of high-disagreement, non-membrane, moderately disordered candidates that may be worth case-study discussion.

# %% [markdown]
# ## 14. PDBFlex ablation: what if we remove it completely?
#
# Because PDBFlex repeatedly appears as an outlier, we ran a direct ablation: same target set, same windows, same scoring pipeline, but with the `pdbflex` predictor removed before calibration and scoring.
#
# Command:
#
# ```bash
# python3 scripts/analyze_contested_regions.py \
#   --target-dataset plddt \
#   --exclude-predictors pdbflex \
#   --output-dir results/contested_regions/plddt_no_pdbflex
#
# python3 scripts/compare_contested_ablation.py \
#   --baseline-dir results/contested_regions/plddt \
#   --ablation-dir results/contested_regions/plddt_no_pdbflex \
#   --output-dir results/contested_regions/pdbflex_ablation_comparison
# ```

# %%
ABLATION = RESULTS / 'contested_regions' / 'pdbflex_ablation_comparison'
score_summary = pd.read_csv(ABLATION / 'score_summary.csv', index_col=0)
top_overlap = pd.read_csv(ABLATION / 'top_region_overlap_summary.csv')
type_comparison = pd.read_csv(ABLATION / 'disagreement_type_count_comparison.csv')
display(score_summary)
display(top_overlap)
display(type_comparison)
# Out:
#                          with_pdbflex  without_pdbflex  \
# priority_score               0.196749         0.157496
# mean_disagreement            0.328802         0.266274
# boundary_uncertainty         0.615617         0.607211
# nmr_suitability              0.989596         0.989596
# concept_family_spread_z      0.595372         0.314836
# possible_more_score          0.632217         0.600992
# tmh_like_score               0.030451         0.030451
#
#                          delta_without_pdbflex_minus_with_pdbflex
# priority_score                                          -0.039253
# mean_disagreement                                       -0.062528
# boundary_uncertainty                                    -0.008406
# nmr_suitability                                          0.000000
# concept_family_spread_z                                 -0.280536
# possible_more_score                                     -0.031225
# tmh_like_score                                           0.000000
#    top_n  overlap_n  union_n   jaccard
# 0     25         13       37  0.351351
#                         disagreement_type  with_pdbflex  without_pdbflex  \
# 0                general_predictor_spread          4824             5371
# 1                    pdbflex_high_outlier           445                0
# 2  possible_molecular_recognition_element           206              118
# 3     tmh_or_signal_peptide_like_artifact            80               80
# 4                 nmr_vs_curated_conflict            40               49
# 5                 broad_multimodel_spread            38               15
# 6               plddt_uncertainty_outlier            12               12
#
#    delta_without_minus_with
# 0                       547
# 1                      -445
# 2                       -88
# 3                         0
# 4                         9
# 5                       -23
# 6                         0

# %%
for name in [
    'score_summary_comparison.png',
    'rank_stability_scatter.png',
    'disagreement_type_comparison.png',
]:
    path = ABLATION / name
    if path.exists():
        display(Markdown(f'### `{path.relative_to(ROOT)}`'))
        display(Image(filename=str(path)))
# Out:
# ### `results/contested_regions/pdbflex_ablation_comparison/score_summary_comparison.png`
# ### `results/contested_regions/pdbflex_ablation_comparison/rank_stability_scatter.png`
# ### `results/contested_regions/pdbflex_ablation_comparison/disagreement_type_comparison.png`

# %% [markdown]
# **Interpretation:** removing PDBFlex lowers the median disagreement score and especially the concept-family spread. The global ranking remains correlated, but the very top candidates change substantially: only 13 of the top 25 windows are shared. This means PDBFlex is not only adding random noise; it creates a distinct flexibility-vs-disorder axis. If the scientific question is strictly intrinsic disorder, excluding it is defensible. If the question is broader concept conflict, excluding it removes useful information.

# %% [markdown]
# ## 10. Export manifest
#
# Run this at the end to list all figures generated by this notebook.

# %%
manifest = pd.DataFrame([
    {'figure': p.name, 'path': str(p.relative_to(ROOT)), 'size_kb': round(p.stat().st_size / 1024, 1)}
    for p in sorted(OUT.glob('*.png'))
])
manifest
# Out:
#                                  figure  \
# 0  annotation_concept_compatibility.png
# 1  contested_region_scoring_concept.png
# 2           exact_vs_mmseqs80_delta.png
# 3         human_annotation_coverage.png
# 4            region_level_agreement.png
# 5     same_vs_cross_concept_summary.png
# 6   top_contested_regions_replotted.png
#
#                                                 path  size_kb
# 0  results/weekly_contested_regions/annotation_co...    158.3
# 1  results/weekly_contested_regions/contested_reg...    108.8
# 2  results/weekly_contested_regions/exact_vs_mmse...    164.7
# 3  results/weekly_contested_regions/human_annotat...     77.4
# 4  results/weekly_contested_regions/region_level_...    125.1
# 5  results/weekly_contested_regions/same_vs_cross...    105.2
# 6  results/weekly_contested_regions/top_contested...    136.3
